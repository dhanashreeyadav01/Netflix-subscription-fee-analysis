# %% [markdown]
# Objective: To perform EDA and visualization

# %%
#Importing all the necessary libraries:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv(r"D:\dhanashree\Management Internship Program\Datasets_MIP_PGDM_Ti 6_2020-22\Netflix subscription fee_Analysis.csv")
data.head()
# Out:
#   Country_code    Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0           ar  Argentina                4760             3154           1606
# 1           au  Australia                6114             4050           2064
# 2           at    Austria                5640             3779           1861
# 3           be    Belgium                4990             3374           1616
# 4           bo    Bolivia                4991             3155           1836
#
#    Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                        3.74                           6.30
# 1                        7.84                          12.12
# 2                        9.03                          14.67
# 3                       10.16                          15.24
# 4                        7.99                          10.99
#
#    Cost Per Month - Premium ($)
# 0                          9.26
# 1                         16.39
# ...

# %%
data=data.drop('Country_code',axis=1)
data.head()
# Out:
#      Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0  Argentina                4760             3154           1606
# 1  Australia                6114             4050           2064
# 2    Austria                5640             3779           1861
# 3    Belgium                4990             3374           1616
# 4    Bolivia                4991             3155           1836
#
#    Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                        3.74                           6.30
# 1                        7.84                          12.12
# 2                        9.03                          14.67
# 3                       10.16                          15.24
# 4                        7.99                          10.99
#
#    Cost Per Month - Premium ($)
# 0                          9.26
# 1                         16.39
# 2                         20.32
# 3                         20.32
# 4                         13.99

# %%
data.shape
# Out:
# (65, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        65 non-null     object
#  1   Total Library Size             65 non-null     int64
#  2   No. of TV Shows                65 non-null     int64
#  3   No. of Movies                  65 non-null     int64
#  4   Cost Per Month - Basic ($)     65 non-null     float64
#  5   Cost Per Month - Standard ($)  65 non-null     float64
#  6   Cost Per Month - Premium ($)   65 non-null     float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 3.7+ KB

# %%
data.isnull().sum()
# Out:
# Country                          0
# Total Library Size               0
# No. of TV Shows                  0
# No. of Movies                    0
# Cost Per Month - Basic ($)       0
# Cost Per Month - Standard ($)    0
# Cost Per Month - Premium ($)     0
# dtype: int64

# %%
print(data['Country'].unique())
print('The no. of countries:',data['Country'].nunique())
# Out:
# ['Argentina' 'Australia' 'Austria' 'Belgium' 'Bolivia' 'Brazil' 'Bulgaria'
#  'Canada' 'Chile' 'Colombia' 'Costa Rica' 'Croatia' 'Czechia' 'Denmark'
#  'Ecuador' 'Estonia' 'Finland' 'France' 'Germany' 'Gibraltar' 'Greece'
#  'Guatemala' 'Honduras' 'Hong Kong' 'Hungary' 'Iceland' 'India'
#  'Indonesia' 'Ireland' 'Israel' 'Italy' 'Japan' 'Latvia' 'Liechtenstein'
#  'Lithuania' 'Malaysia' 'Mexico' 'Moldova' 'Monaco' 'Netherlands'
#  'New Zealand' 'Norway' 'Paraguay' 'Peru' 'Philippines' 'Poland'
#  'Portugal' 'Romania' 'Russia' 'San Marino' 'Singapore' 'Slovakia'
#  'South Africa' 'South Korea' 'Spain' 'Sweden' 'Switzerland' 'Taiwan'
#  'Thailand' 'Turkey' 'Ukraine' 'United Kingdom' 'United States' 'Uruguay'
#  'Venezuela']
# The no. of countries: 65

# %%
data['Total Library Size'].unique()
# Out:
# array([4760, 6114, 5640, 4990, 4991, 4972, 6797, 6239, 4994, 4988, 2274,
#        7325, 4558, 4992, 6456, 4045, 5445, 5668, 6167, 4772, 4767, 4989,
#        4746, 6884, 6387, 5843, 3887, 6486, 5713, 5183, 5475, 6450, 3048,
#        6462, 5952, 4993, 3937, 5804, 5376, 6084, 4528, 4797, 4986, 6362,
#        5109, 5047, 5303, 5711, 2310, 6303, 7035, 5736, 5195, 5229, 4361,
#        5506, 5105, 4948, 4639, 5336, 6643, 5818], dtype=int64)

# %%
plt.figure(figsize=(20,15))
sns.countplot(data['Total Library Size'], palette = 'twilight')

# %%
data['No. of TV Shows'].unique()
# Out:
# array([3154, 4050, 3779, 3374, 3155, 3162, 4819, 4311, 3156, 3152, 1675,
#        5234, 2978, 4486, 2638, 3604, 3814, 4079, 3344, 2883, 4802, 4426,
#        3718, 2449, 4515, 3650, 3545, 3619, 4479, 1712, 4490, 3565, 3158,
#        2473, 3806, 4003, 2955, 4154, 3512, 3419, 3832, 3624, 1937, 4109,
#        5055, 3686, 3334, 3536, 2973, 3654, 3134, 2977, 2930, 3261, 4551,
#        3826], dtype=int64)

# %%
plt.figure(figsize=(15,10))
sns.countplot(data['No. of TV Shows'], palette = 'twilight')

# %%
data['No. of Movies'].unique()
# Out:
# array([1606, 2064, 1861, 1616, 1836, 1810, 1978, 1928, 1838, 1835,  599,
#        2091, 1580, 1837, 1970, 1407, 1841, 1854, 2088, 1428, 1613, 1863,
#        2082, 1961, 2125, 1438, 1971, 2063, 1638, 1856, 1336, 1972, 2387,
#        1464, 1998, 1597, 2081, 1573, 1642, 1831, 2208, 1628, 1471, 2087,
#         373, 2194, 1980, 2050, 1693, 1388, 1852, 1709, 2075, 2092, 1992,
#        1643], dtype=int64)

# %%
plt.figure(figsize=(15,10))
sns.countplot(data['No. of Movies'], palette = 'twilight')

# %%
data['Cost Per Month - Basic ($)'].unique()
# Out:
# array([ 3.74,  7.84,  9.03, 10.16,  7.99,  4.61,  7.91,  7.07,  4.31,
#         8.99,  8.83, 12.  ,  8.08,  7.64,  2.64,  8.36, 10.56,  8.73,
#        12.88,  8.29,  6.62,  8.8 ,  9.94,  6.11,  7.35,  7.13,  8.13,
#         9.51,  6.26,  8.07, 10.9 ,  9.74,  8.34,  1.97,  5.64])

# %%
plt.figure(figsize=(15,10))
sns.countplot(data['Cost Per Month - Basic ($)'], palette = 'twilight')

# %%
data['Cost Per Month - Standard ($)'].unique()
# Out:
# array([ 6.3 , 12.12, 14.67, 15.24, 10.99,  7.11, 11.29, 11.87,  9.91,
#         6.86, 12.99, 11.49, 15.04, 13.54, 12.42, 10.  , 10.71,  6.61,
#        10.66, 15.05, 13.13, 20.46, 10.65, 10.43, 12.53, 12.17,  8.56,
#         9.14, 10.58, 10.84, 12.81, 10.05, 11.47, 14.2 , 11.9 ,  3.  ,
#         8.46, 13.2 , 13.99])

# %%
plt.figure(figsize=(15,10))
sns.countplot(data['Cost Per Month - Standard ($)'], palette = 'twilight')

# %%
data['Cost Per Month - Premium ($)'].unique()
# Out:
# array([ 9.26, 16.39, 20.32, 13.99,  9.96, 13.54, 15.03, 12.74,  9.93,
#        15.99, 14.15, 19.6 , 18.06, 15.8 , 11.93, 13.78,  8.6 , 12.96,
#        19.54, 17.45, 26.96, 13.02, 14.24, 16.94, 17.75, 14.69, 11.01,
#        10.93, 14.76, 13.56, 16.11, 12.58, 14.45, 19.7 , 14.07, 12.52,
#         4.02, 11.29, 18.48, 17.99])

# %%
plt.figure(figsize=(15,10))
sns.countplot(data['Cost Per Month - Premium ($)'], palette = 'twilight')

# %%
plt.figure(figsize=(10,15))
sns.barplot(data=data, y="Country", x="Total Library Size",color='purple')

# %%
top_10_country = data['Country'][:10]
plt.figure(figsize = (10,5))
chart = data.groupby(top_10_country)['Total Library Size'].sum().sort_values(ascending = False).plot(kind = 'bar', color = 'purple')
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45)
plt.title('Top of Country based on Total Library Size', fontsize = 15, pad = 12)
plt.xlabel('Country', fontsize = 12)
plt.ylabel('Total Library Size', fontsize = 12)
plt.show()

# %%
plt.figure(figsize=(10,15))
sns.barplot(data=data, y="Country", x="No. of TV Shows",color='purple')

# %%
top_10_country = data['Country'][:10]
plt.figure(figsize = (10,5))
chart = data.groupby(top_10_country)['No. of TV Shows'].sum().sort_values(ascending = False).plot(kind = 'bar', color = 'purple')
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45)
plt.title('Top of Country based on No. of TV Shows', fontsize = 15, pad = 12)
plt.xlabel('Country', fontsize = 12)
plt.ylabel('No. of TV Shows', fontsize = 12)
plt.show()

# %%
plt.figure(figsize=(10,15))
sns.barplot(data=data, y="Country", x="No. of Movies",color='purple')

# %%
top_10_country = data['Country'][:10]
plt.figure(figsize = (10,5))
chart = data.groupby(top_10_country)['No. of Movies'].sum().sort_values(ascending = False).plot(kind = 'bar', color = 'purple')
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45)
plt.title('Top of Country based on No. of Movies', fontsize = 15, pad = 12)
plt.xlabel('Country', fontsize = 12)
plt.ylabel('No. of Movies', fontsize = 12)
plt.show()

# %%
top_10_country = data['Country'][:10]
plt.figure(figsize = (10,5))
chart = data.groupby(top_10_country)['Cost Per Month - Basic ($)'].sum().sort_values(ascending = False).plot(kind = 'bar', color = 'purple')
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45)
plt.title('Top of Country based on Total Basic Cost Per Month', fontsize = 15, pad = 12)
plt.xlabel('Country', fontsize = 12)
plt.ylabel('Total Basic Cost Per Month ($)', fontsize = 12)
plt.show()

# %%
top_10_country = data['Country'][:10]
plt.figure(figsize = (10,5))
chart = data.groupby(top_10_country)['Cost Per Month - Standard ($)'].sum().sort_values(ascending = False).plot(kind = 'bar', color = 'purple')
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45)
plt.title('Top of Country based on Total Standard Cost Per Month', fontsize = 15, pad = 12)
plt.xlabel('Country', fontsize = 12)
plt.ylabel('Total Standard Cost Per Month ($)', fontsize = 12)
plt.show()

# %%
top_10_country = data['Country'][:10]
plt.figure(figsize = (10,5))
chart = data.groupby(top_10_country)['Cost Per Month - Premium ($)'].sum().sort_values(ascending = False).plot(kind = 'bar', color = 'purple')
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45)
plt.title('Top of Country based on Total Premium Cost Per Month', fontsize = 15, pad = 12)
plt.xlabel('Country', fontsize = 12)
plt.ylabel('Total Premium Cost Per Month ($)', fontsize = 12)
plt.show()

# %%
data.describe()
# Out:
#        Total Library Size  No. of TV Shows  No. of Movies  \
# count           65.000000        65.000000      65.000000
# mean          5314.415385      3518.953846    1795.461538
# std            980.322633       723.010556     327.279748
# min           2274.000000      1675.000000     373.000000
# 25%           4948.000000      3154.000000    1628.000000
# 50%           5195.000000      3512.000000    1841.000000
# 75%           5952.000000      3832.000000    1980.000000
# max           7325.000000      5234.000000    2387.000000
#
#        Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# count                   65.000000                      65.000000
# mean                     8.368462                      11.990000
# std                      1.937819                       2.863979
# min                      1.970000                       3.000000
# 25%                      7.990000                      10.710000
# ...

# %%
data['Cost Per Month - Basic ($)'].median()
# Out:
# 8.99

# %%
data['Cost Per Month - Standard ($)'].median()
# Out:
# 11.49

# %%
data['Cost Per Month - Premium ($)'].median()
# Out:
# 14.45

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
X=data.drop(columns=["Cost Per Month - Premium ($)","Country"],axis=1)
Y=data["Cost Per Month - Premium ($)"]
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)
lm=LinearRegression()
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
prediction=lm.predict(X_test)
prediction
# Out:
# array([14.0914462 , 19.52852214, 11.06550975, 18.72254778, 13.83124967,
#        28.12118915, 17.44530601, 16.17608311,  9.77248556, 17.04040212,
#        14.13280915, 19.98667039, 14.66143461])

# %%
comparission=pd.DataFrame({"Actual":Y_test,"Predictions":prediction})
comparission
# Out:
#     Actual  Predictions
# 45   14.76    14.091446
# 29   19.54    19.528522
# 43   11.01    11.065510
# 62   17.99    18.722548
# 34   13.54    13.831250
# 33   26.96    28.121189
# 31   17.45    17.445306
# 40   16.94    16.176083
# 26    8.60     9.772486
# 63   15.99    17.040402
# 22   13.99    14.132809
# 2    20.32    19.986670
# 11   13.54    14.661435

# %%
score=lm.score(X_test,Y_test)*100
score
# Out:
# 97.30632985576588
